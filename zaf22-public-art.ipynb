# %% [markdown]
# The dataset I used to describe the best neighborhood in Pittsburgh is the one with the most public art projects.

# %%
#imports
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Data is being read through csv file
parks = pd.read_csv("https://data.wprdc.org/datastore/dump/00d74e83-8a23-486e-841b-286e1332a151",
                           index_col="title", 
                           parse_dates=True)
parks.head()
# Out:
#                                        id  name            artist_name  \
# title
# Oakwood Road Monument           812728309  1001                    NaN
# Middle East Memorial Plaque    2032091917   129                    NaN
# L'Enfant                       1447629273   143      Paul Roger-Bloche
# Veterans Memorial (Brookline)  1935017944   148         Not Applicable
# Oakley Street Mosaic Steps      752311791   153  Laura Jean McLaughlin
#
#                                                   art_type  \
# title
# Oakwood Road Monument                                  NaN
# Middle East Memorial Plaque                  War Memorials
# L'Enfant                                      Historic Art
# Veterans Memorial (Brookline)                War Memorials
# Oakley Street Mosaic Steps     Modern and Contemporary Art
#
#                                              park image  \
# title
# Oakwood Road Monument                         NaN   NaN
# ...

# %%
#Lists the amount of times each neighborhood had a public art project in the dataset.
parks['neighborhood'].value_counts()
# Out:
# Central Business District    27
# Squirrel Hill South          22
# Allegheny Center             18
# South Side Flats             10
# Highland Park                10
# Beechview                     8
# North Shore                   7
# Shadyside                     6
# Brighton Heights              5
# Central Oakland               5
# Lower Lawrenceville           5
# Spring Hill-City View         4
# Hazelwood                     4
# Beltzhoover                   3
# Carrick                       3
# South Side Slopes             3
# Point Breeze                  3
# Greenfield                    3
# Duquesne Heights              3
# Spring Garden                 2
# Regent Square                 2
# Brookline                     2
# East Allegheny                2
# Lincoln-Lemington-Belmar      2
# Central Lawrenceville         2
# Allentown                     2
# Perry North                   2
# Elliott                       2
# West End                      2
# ...

# %% [markdown]
# As you can see, the Central Business District has the most public art in Pittsburgh with 27 pieces. Quite a few cities share the lowest amount of 1, including Sheraden and Stanton Heights.

# %%
#A bar graph of the amount of art projects in each neighborhood.
parks['neighborhood'].value_counts().plot(kind='bar', width=.4, figsize=(25,10), position=0)

# %% [markdown]
# Above is a bar graph of the amount of art projects in each neighborhood ranked from highest to lowest. I figured this would be easier to look at and understand.
